# %% [markdown]
# # MBK competition

# %%
import numpy as np
import pandas as pd
import sklearn.preprocessing as prp

pd.set_option('display.max_columns', None)

train = pd.read_csv('train_dataset_hackathon_mkb.csv', encoding='cp1251', delimiter=';')
test = pd.read_csv('test_dataset_hackathon_mkb.csv', encoding='cp1251', delimiter=';')
print(train.shape, test.shape)
# Out:
# (17891, 124) (7330, 123)

# %% [markdown]
# ## генерация признаков
# - тут немного, я попробовал много вариантов, но оставил только те, которые дали прирост скора.
# - недостаточно для повышенного скора, как оказалось (топ-2 решение генерировал 200+ фичей)

# %%
def make_features(data):

    data['CITIZENSHIP_NAME'] = data['CITIZENSHIP_NAME'].fillna(-1).map({-1: -1, 'Российская Федерация': 4, 'Таджикистан': 3, 'Казахстан': 2, 'Армения': 1})
    data['SEX_NAME'] = data['CITIZENSHIP_NAME'].fillna(0).map({0: 0, 'мужской': 1, 'женский': -1})
    cat_names = ['OKFS_GROUP', 'OKOPF_GROUP', 'OKOGU_GROUP'] + ['WORKERSRANGE', 'OKVED_CODE'] + ['OKATO_FED','OKTMO_FED']
    date_names = ['SIGN_DATE', 'DATEFIRSTREG', 'TAXREG_REGDATE', 'TAXREGPAY_REGDATE', 'BIRTHDATE']
    for name in date_names:
        data[name] = pd.to_datetime(data[name], format = '%d%b%Y:%H:%M:%S', errors = 'coerce')
        data[name + '_dayofweek'] = data[name].dt.dayofweek
    def minus_shift(x):
        diff = (x-x.shift()).dt.days
        return diff.fillna(0)
    data['vari_diff'] = data.groupby('id_client')['SIGN_DATE'].apply(minus_shift)
    data['vari_diff_mean'] = data.groupby('id_client')['vari_diff'].transform('mean')
    # data['vari_diff'] = np.log1p(data_train['vari_diff']) # log-operation
    # data['vari_diff_mean'] = np.log1p(data_train['vari_diff_mean']) # log-operation
    for name in cat_names + date_names+ ['id_client']:
        data[name] = data[name].fillna(-1)
        tmp = data[name].value_counts()
        tmp = tmp + 0.05 * np.random.randn(len(tmp))
        data[name] = data[name].map(tmp)
    # data = pd.get_dummies(data, columns = cat_names)
    
    #for name in cols:
    #    data[name] = prp.StandardScaler().fit_transform(data[[name]])
    
    # data['OKATO_FED'] = np.log1p(data_train['OKATO_FED']) # log-operation
    # data['OKTMO_FED'] = np.log1p(data_train['OKTMO_FED']) # log-operation
    data.fillna(-1, inplace=True)
    return data

# %%
data_train = make_features(train)
data_test = make_features(test)

# %% [markdown]
# ## Модель: lightgbm
# был немножко тюнинг с GridSearchCV

# %%
y = data_train.pop('TARGET').values
data_test = data_test[data_train.columns]

# %%
import lightgbm as lgb
import xgboost as xgb

model = lgb.LGBMClassifier(num_leaves=30, learning_rate=0.05, n_estimators=500)
model.fit(data_train, y)
pred = model.predict_proba(data_test)[:, 1]

# %%
df = pd.DataFrame({'id_contract': data_test.id_contract.values, 'TARGET': pred})
df.to_csv('lightgbm8.csv', sep=';', index=False)

# %% [markdown]
# какие фичи дали прирост, а какие нет
# 1. vari_diff +
# 2. log-operation -
# 3. 'OKATO_FED','OKTMO_FED' log???
# 4. dayofweek +
# 5. MinMaxScaler of F --
# 6. 'id_client', 'id_contrast' +

# %% [markdown]
# ## Модель: catboost

# %%
y = data_train.pop('TARGET').values
data_test = data_test[data_train.columns]

# %%
import catboost as cb
model = cb.CatBoostClassifier(iterations=300, depth=6,learning_rate=0.1, custom_loss='AUC', eval_metric='AUC')

model.fit(data_train, y)
pred = model.predict_proba(data_test)[:, 1]
# Out:
# 0:	total: 74.8ms	remaining: 22.4s
# 1:	total: 90ms	remaining: 13.4s
# 2:	total: 105ms	remaining: 10.4s
# 3:	total: 119ms	remaining: 8.83s
# 4:	total: 134ms	remaining: 7.91s
# 5:	total: 148ms	remaining: 7.25s
# 6:	total: 165ms	remaining: 6.89s
# 7:	total: 179ms	remaining: 6.55s
# 8:	total: 194ms	remaining: 6.28s
# 9:	total: 208ms	remaining: 6.04s
# 10:	total: 222ms	remaining: 5.84s
# 11:	total: 237ms	remaining: 5.69s
# 12:	total: 255ms	remaining: 5.64s
# 13:	total: 271ms	remaining: 5.54s
# 14:	total: 288ms	remaining: 5.48s
# 15:	total: 303ms	remaining: 5.38s
# 16:	total: 318ms	remaining: 5.29s
# 17:	total: 332ms	remaining: 5.2s
# 18:	total: 346ms	remaining: 5.12s
# 19:	total: 360ms	remaining: 5.04s
# 20:	total: 374ms	remaining: 4.97s
# 21:	total: 387ms	remaining: 4.89s
# 22:	total: 402ms	remaining: 4.84s
# 23:	total: 419ms	remaining: 4.81s
# 24:	total: 433ms	remaining: 4.76s
# 25:	total: 447ms	remaining: 4.71s
# 26:	total: 461ms	remaining: 4.66s
# 27:	total: 477ms	remaining: 4.63s
# 28:	total: 494ms	remaining: 4.61s
# 29:	total: 509ms	remaining: 4.58s
# 30:	total: 523ms	remaining: 4.54s
# 31:	total: 537ms	remaining: 4.5s
# 32:	total: 551ms	remaining: 4.45s
# 33:	total: 566ms	remaining: 4.43s
# 34:	total: 585ms	remaining: 4.43s
# 35:	total: 599ms	remaining: 4.39s
# 36:	total: 614ms	remaining: 4.36s
# 37:	total: 629ms	remaining: 4.33s
# 38:	total: 644ms	remaining: 4.31s
# 39:	total: 662ms	remaining: 4.3s
# 40:	total: 678ms	remaining: 4.28s
# 41:	total: 693ms	remaining: 4.26s
# 42:	total: 711ms	remaining: 4.25s
# 43:	total: 725ms	remaining: 4.22s
# 44:	total: 740ms	remaining: 4.19s
# 45:	total: 758ms	remaining: 4.18s
# 46:	total: 772ms	remaining: 4.16s
# 47:	total: 788ms	remaining: 4.14s
# 48:	total: 805ms	remaining: 4.12s
# 49:	total: 821ms	remaining: 4.11s
# 50:	total: 835ms	remaining: 4.08s
# 51:	total: 849ms	remaining: 4.05s
# 52:	total: 863ms	remaining: 4.02s
# 53:	total: 881ms	remaining: 4.01s
# 54:	total: 897ms	remaining: 3.99s
# 55:	total: 912ms	remaining: 3.97s
# 56:	total: 926ms	remaining: 3.95s
# 57:	total: 942ms	remaining: 3.93s
# 58:	total: 959ms	remaining: 3.92s
# 59:	total: 973ms	remaining: 3.89s
# 60:	total: 988ms	remaining: 3.87s
# 61:	total: 1s	remaining: 3.85s
# 62:	total: 1.02s	remaining: 3.83s
# 63:	total: 1.03s	remaining: 3.81s
# 64:	total: 1.05s	remaining: 3.78s
# 65:	total: 1.06s	remaining: 3.77s
# 66:	total: 1.08s	remaining: 3.76s
# 67:	total: 1.1s	remaining: 3.75s
# 68:	total: 1.11s	remaining: 3.73s
# 69:	total: 1.13s	remaining: 3.71s
# 70:	total: 1.15s	remaining: 3.71s
# 71:	total: 1.17s	remaining: 3.69s
# 72:	total: 1.18s	remaining: 3.68s
# 73:	total: 1.2s	remaining: 3.67s
# 74:	total: 1.22s	remaining: 3.66s
# 75:	total: 1.23s	remaining: 3.64s
# 76:	total: 1.25s	remaining: 3.63s
# 77:	total: 1.27s	remaining: 3.62s
# 78:	total: 1.29s	remaining: 3.62s
# 79:	total: 1.31s	remaining: 3.6s
# 80:	total: 1.33s	remaining: 3.59s
# 81:	total: 1.34s	remaining: 3.57s
# 82:	total: 1.36s	remaining: 3.56s
# 83:	total: 1.38s	remaining: 3.54s
# 84:	total: 1.39s	remaining: 3.53s
# 85:	total: 1.41s	remaining: 3.51s
# 86:	total: 1.43s	remaining: 3.49s
# 87:	total: 1.45s	remaining: 3.48s
# 88:	total: 1.46s	remaining: 3.47s
# 89:	total: 1.48s	remaining: 3.45s
# 90:	total: 1.5s	remaining: 3.43s
# 91:	total: 1.51s	remaining: 3.41s
# 92:	total: 1.52s	remaining: 3.39s
# 93:	total: 1.54s	remaining: 3.37s
# 94:	total: 1.55s	remaining: 3.35s
# 95:	total: 1.56s	remaining: 3.33s
# 96:	total: 1.58s	remaining: 3.31s
# 97:	total: 1.6s	remaining: 3.29s
# 98:	total: 1.61s	remaining: 3.27s
# 99:	total: 1.63s	remaining: 3.25s
# 100:	total: 1.64s	remaining: 3.23s
# 101:	total: 1.66s	remaining: 3.21s
# 102:	total: 1.67s	remaining: 3.2s
# 103:	total: 1.69s	remaining: 3.18s
# 104:	total: 1.7s	remaining: 3.16s
# 105:	total: 1.72s	remaining: 3.14s
# 106:	total: 1.73s	remaining: 3.13s
# 107:	total: 1.76s	remaining: 3.14s
# 108:	total: 1.79s	remaining: 3.13s
# 109:	total: 1.81s	remaining: 3.12s
# 110:	total: 1.83s	remaining: 3.11s
# 111:	total: 1.85s	remaining: 3.1s
# 112:	total: 1.87s	remaining: 3.1s
# 113:	total: 1.89s	remaining: 3.09s
# 114:	total: 1.91s	remaining: 3.07s
# 115:	total: 1.93s	remaining: 3.06s
# 116:	total: 1.95s	remaining: 3.05s
# 117:	total: 1.97s	remaining: 3.04s
# 118:	total: 1.99s	remaining: 3.03s
# 119:	total: 2.01s	remaining: 3.01s
# 120:	total: 2.03s	remaining: 3s
# 121:	total: 2.05s	remaining: 2.99s
# 122:	total: 2.07s	remaining: 2.97s
# 123:	total: 2.09s	remaining: 2.96s
# 124:	total: 2.11s	remaining: 2.95s
# 125:	total: 2.13s	remaining: 2.94s
# 126:	total: 2.15s	remaining: 2.92s
# 127:	total: 2.17s	remaining: 2.91s
# 128:	total: 2.18s	remaining: 2.89s
# 129:	total: 2.2s	remaining: 2.88s
# 130:	total: 2.22s	remaining: 2.87s
# 131:	total: 2.24s	remaining: 2.85s
# 132:	total: 2.26s	remaining: 2.84s
# 133:	total: 2.28s	remaining: 2.83s
# 134:	total: 2.3s	remaining: 2.81s
# 135:	total: 2.32s	remaining: 2.8s
# 136:	total: 2.35s	remaining: 2.79s
# 137:	total: 2.37s	remaining: 2.78s
# 138:	total: 2.39s	remaining: 2.77s
# 139:	total: 2.41s	remaining: 2.75s
# 140:	total: 2.43s	remaining: 2.74s
# 141:	total: 2.45s	remaining: 2.72s
# 142:	total: 2.46s	remaining: 2.71s
# 143:	total: 2.48s	remaining: 2.69s
# 144:	total: 2.5s	remaining: 2.67s
# 145:	total: 2.52s	remaining: 2.66s
# 146:	total: 2.54s	remaining: 2.64s
# 147:	total: 2.55s	remaining: 2.62s
# 148:	total: 2.57s	remaining: 2.6s
# 149:	total: 2.59s	remaining: 2.59s
# 150:	total: 2.6s	remaining: 2.57s
# 151:	total: 2.62s	remaining: 2.55s
# 152:	total: 2.64s	remaining: 2.53s
# 153:	total: 2.65s	remaining: 2.52s
# 154:	total: 2.67s	remaining: 2.5s
# 155:	total: 2.69s	remaining: 2.48s
# 156:	total: 2.71s	remaining: 2.47s
# 157:	total: 2.73s	remaining: 2.45s
# 158:	total: 2.74s	remaining: 2.43s
# 159:	total: 2.76s	remaining: 2.42s
# 160:	total: 2.78s	remaining: 2.4s
# 161:	total: 2.79s	remaining: 2.38s
# 162:	total: 2.81s	remaining: 2.36s
# 163:	total: 2.83s	remaining: 2.35s
# 164:	total: 2.85s	remaining: 2.33s
# 165:	total: 2.87s	remaining: 2.31s
# 166:	total: 2.89s	remaining: 2.3s
# 167:	total: 2.9s	remaining: 2.28s
# 168:	total: 2.92s	remaining: 2.27s
# 169:	total: 2.94s	remaining: 2.25s
# 170:	total: 2.96s	remaining: 2.23s
# 171:	total: 2.98s	remaining: 2.21s
# 172:	total: 2.99s	remaining: 2.2s
# 173:	total: 3.01s	remaining: 2.18s
# 174:	total: 3.03s	remaining: 2.16s
# 175:	total: 3.04s	remaining: 2.14s
# 176:	total: 3.06s	remaining: 2.13s
# 177:	total: 3.07s	remaining: 2.11s
# 178:	total: 3.09s	remaining: 2.09s
# 179:	total: 3.11s	remaining: 2.07s
# 180:	total: 3.13s	remaining: 2.05s
# 181:	total: 3.14s	remaining: 2.04s
# 182:	total: 3.16s	remaining: 2.02s
# 183:	total: 3.17s	remaining: 2s
# 184:	total: 3.19s	remaining: 1.98s
# 185:	total: 3.2s	remaining: 1.96s
# 186:	total: 3.21s	remaining: 1.94s
# 187:	total: 3.23s	remaining: 1.92s
# 188:	total: 3.24s	remaining: 1.9s
# 189:	total: 3.25s	remaining: 1.88s
# 190:	total: 3.27s	remaining: 1.86s
# 191:	total: 3.28s	remaining: 1.85s
# 192:	total: 3.3s	remaining: 1.83s
# 193:	total: 3.31s	remaining: 1.81s
# 194:	total: 3.33s	remaining: 1.79s
# 195:	total: 3.34s	remaining: 1.77s
# 196:	total: 3.35s	remaining: 1.75s
# 197:	total: 3.37s	remaining: 1.74s
# 198:	total: 3.38s	remaining: 1.72s
# 199:	total: 3.4s	remaining: 1.7s
# 200:	total: 3.41s	remaining: 1.68s
# 201:	total: 3.42s	remaining: 1.66s
# 202:	total: 3.44s	remaining: 1.64s
# 203:	total: 3.45s	remaining: 1.62s
# 204:	total: 3.46s	remaining: 1.6s
# 205:	total: 3.48s	remaining: 1.59s
# 206:	total: 3.49s	remaining: 1.57s
# 207:	total: 3.5s	remaining: 1.55s
# 208:	total: 3.52s	remaining: 1.53s
# 209:	total: 3.54s	remaining: 1.51s
# 210:	total: 3.55s	remaining: 1.5s
# 211:	total: 3.56s	remaining: 1.48s
# 212:	total: 3.58s	remaining: 1.46s
# 213:	total: 3.59s	remaining: 1.44s
# 214:	total: 3.61s	remaining: 1.43s
# 215:	total: 3.62s	remaining: 1.41s
# 216:	total: 3.63s	remaining: 1.39s
# 217:	total: 3.65s	remaining: 1.37s
# 218:	total: 3.66s	remaining: 1.35s
# 219:	total: 3.67s	remaining: 1.34s
# 220:	total: 3.69s	remaining: 1.32s
# 221:	total: 3.7s	remaining: 1.3s
# 222:	total: 3.72s	remaining: 1.28s
# 223:	total: 3.74s	remaining: 1.27s
# 224:	total: 3.76s	remaining: 1.25s
# 225:	total: 3.77s	remaining: 1.24s
# 226:	total: 3.79s	remaining: 1.22s
# 227:	total: 3.81s	remaining: 1.2s
# 228:	total: 3.84s	remaining: 1.19s
# 229:	total: 3.85s	remaining: 1.17s
# 230:	total: 3.87s	remaining: 1.16s
# 231:	total: 3.89s	remaining: 1.14s
# 232:	total: 3.9s	remaining: 1.12s
# 233:	total: 3.92s	remaining: 1.1s
# 234:	total: 3.94s	remaining: 1.09s
# 235:	total: 3.96s	remaining: 1.07s
# 236:	total: 3.98s	remaining: 1.06s
# 237:	total: 4s	remaining: 1.04s
# 238:	total: 4.01s	remaining: 1.02s
# 239:	total: 4.03s	remaining: 1.01s
# 240:	total: 4.05s	remaining: 991ms
# 241:	total: 4.06s	remaining: 974ms
# 242:	total: 4.08s	remaining: 957ms
# 243:	total: 4.09s	remaining: 940ms
# 244:	total: 4.11s	remaining: 923ms
# 245:	total: 4.13s	remaining: 907ms
# 246:	total: 4.15s	remaining: 891ms
# 247:	total: 4.17s	remaining: 874ms
# 248:	total: 4.18s	remaining: 857ms
# 249:	total: 4.2s	remaining: 840ms
# 250:	total: 4.22s	remaining: 823ms
# 251:	total: 4.23s	remaining: 806ms
# 252:	total: 4.25s	remaining: 789ms
# 253:	total: 4.27s	remaining: 773ms
# 254:	total: 4.28s	remaining: 756ms
# 255:	total: 4.3s	remaining: 739ms
# 256:	total: 4.32s	remaining: 722ms
# 257:	total: 4.33s	remaining: 706ms
# 258:	total: 4.35s	remaining: 688ms
# 259:	total: 4.36s	remaining: 671ms
# 260:	total: 4.38s	remaining: 654ms
# 261:	total: 4.39s	remaining: 637ms
# 262:	total: 4.41s	remaining: 620ms
# 263:	total: 4.42s	remaining: 603ms
# 264:	total: 4.43s	remaining: 586ms
# 265:	total: 4.45s	remaining: 569ms
# 266:	total: 4.46s	remaining: 551ms
# 267:	total: 4.47s	remaining: 534ms
# 268:	total: 4.49s	remaining: 517ms
# 269:	total: 4.5s	remaining: 500ms
# 270:	total: 4.52s	remaining: 483ms
# 271:	total: 4.53s	remaining: 466ms
# 272:	total: 4.54s	remaining: 450ms
# 273:	total: 4.56s	remaining: 433ms
# 274:	total: 4.58s	remaining: 416ms
# 275:	total: 4.59s	remaining: 399ms
# 276:	total: 4.61s	remaining: 382ms
# 277:	total: 4.62s	remaining: 366ms
# 278:	total: 4.64s	remaining: 349ms
# 279:	total: 4.65s	remaining: 332ms
# 280:	total: 4.67s	remaining: 316ms
# 281:	total: 4.69s	remaining: 299ms
# 282:	total: 4.71s	remaining: 283ms
# 283:	total: 4.72s	remaining: 266ms
# 284:	total: 4.74s	remaining: 249ms
# 285:	total: 4.76s	remaining: 233ms
# 286:	total: 4.78s	remaining: 216ms
# 287:	total: 4.8s	remaining: 200ms
# 288:	total: 4.81s	remaining: 183ms
# 289:	total: 4.83s	remaining: 167ms
# 290:	total: 4.85s	remaining: 150ms
# 291:	total: 4.86s	remaining: 133ms
# 292:	total: 4.89s	remaining: 117ms
# 293:	total: 4.91s	remaining: 100ms
# 294:	total: 4.92s	remaining: 83.4ms
# 295:	total: 4.94s	remaining: 66.8ms
# 296:	total: 4.96s	remaining: 50.1ms
# 297:	total: 4.98s	remaining: 33.4ms
# 298:	total: 4.99s	remaining: 16.7ms
# 299:	total: 5.01s	remaining: 0us

# %%
df = pd.DataFrame({'id_contract': data_test.id_contract.values, 'TARGET': pred})
df.to_csv('catboost1.csv', sep=';', index=False)
